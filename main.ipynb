# %%
from prepare_saving_as_db import PrepareChain,get_object
text = get_object('question_extract/takken0.txt')
chain = PrepareChain(text)
triplet_freqs = chain.make_triplet_freqs()
chain.save(triplet_freqs, True)
from Generate_text import GenerateText
generator = GenerateText()
print(generator.generate())
# Out:
# [('', '', '', 1), ('', '', 'の', 1), ('', 'の', 'うち', 1), ('の', 'うち', '、', 649), ('うち', '、', '宅地', 147), ('、', '宅地', '建物', 199), ('宅地', '建物', '取引', 499), ('建物', '取引', '業法', 228), ('取引', '業法', 'の', 124), ('業法', 'の', '免許', 2), ('の', '免許', 'を', 3), ('免許', 'を', '受ける', 1), ('を', '受ける', '必要', 5), ('受ける', '必要', 'の', 5), ('必要', 'の', 'ない', 2), ('の', 'ない', 'もの', 2), ('ない', 'もの', 'は', 28), ('もの', 'は', 'どれ', 641), ('は', 'どれ', 'か', 653), ('__BEGIN_SENTENCE__', '', '', 1), ('どれ', 'か', '__END_SENTENCE__', 656), ('A', '（', '個人', 1), ('（', '個人', '）', 4), ('個人', '）', 'の', 1), ('）', 'の', '宅地', 1), ('の', '宅地', '建物', 5), ('の', '免許', '（', 19), ('免許', '（', '以下', 19), ('（', '以下', 'この', 179), ('以下', 'この', '問', 179), ('この', '問', 'において', 199), ('問', 'において', '「', 185), ('において', '「', '免許', 18), ('「', '免許', '」', 19), ('免許', '」', 'という', 19), ('__BEGIN_SENTENCE__', 'A', '（', 1), ('」', 'という', '__END_SENTENCE__', 179), ('）', 'に関する', '次', 103), ('に関する', '次', 'の', 532), ('次', 'の', '記述', 653), ('の', '記述', 'の', 661), ('記述', 'の', 'うち', 661), ('うち', '、', '正しい', 171), ('、', '正しい', 'もの', 387), ('正しい', 'もの', 'は', 400), ('__BEGIN_SENTENCE__', '）', 'に関する', 100), ('建物', '取引', '業', 33), ('取引', '業', 'の', 18), ('業', 'の', '免許', 18), ('__BEGIN_SENTENCE__', '宅地', '建物', 233), ('業法', 'の', '規定', 122), ('の', '規定', 'に', 273), ('規定', 'に', 'よれ', 209), ('に', 'よれ', 'ば', 341), ('よれ', 'ば', '、', 337), ('ば', '、', '正しい', 210), ('もの', 'は', 'いくつ', 27), ('は', 'いくつ', 'ある', 27), ('いくつ', 'ある', 'か', 28), ('ある', 'か', '__END_SENTENCE__', 28), ('建物', '取引', '業者', 223), ('取引', '業者', 'A', 54), ('業者', 'A', '社', 14), ('A', '社', 'が', 6), ('社', 'が', '行う', 2), ('が', '行う', '業務', 8), ('行う', '業務', 'に関する', 8), ('業務', 'に関する', '次', 10), ('規定', 'に', '違反', 35), ('に', '違反', 'する', 11), ('違反', 'する', 'もの', 11), ('する', 'もの', 'は', 12), ('取引', '業者', 'Ａ', 69), ('業者', 'Ａ', '社', 17), ('Ａ', '社', 'による', 1), ('社', 'による', '投資', 1), ('による', '投資', '用', 1), ('投資', '用', 'マンション', 2), ('用', 'マンション', 'の', 2), ('マンション', 'の', '販売', 2), ('の', '販売', 'の', 1), ('販売', 'の', '勧誘', 1), ('の', '勧誘', 'に関する', 1), ('勧誘', 'に関する', '次', 1), ('業者', 'Ａ', 'が', 34), ('Ａ', 'が', '行う', 7), ('に', '違反', 'し', 26), ('違反', 'し', 'ない', 25), ('し', 'ない', 'もの', 36), ('取引', '業法', '（', 55), ('業法', '（', '以下', 55), ('において', '「', '法', 75), ('「', '法', '」', 75), ('法', '」', 'という', 75), ('）', 'に', '規定', 4), ('に', '規定', 'する', 41), ('規定', 'する', '「', 1), ('する', '「', '事務所', 1), ('「', '事務所', '」', 2), ('事務所', '」', 'に関する', 1), ('」', 'に関する', '次', 2), ('うち', '、', '法', 4), ('、', '法', 'の', 4), ('法', 'の', '規定', 46), ('ば', '、', '誤っ', 99), ('、', '誤っ', 'て', 202), ('誤っ', 'て', 'いる', 216), ('て', 'いる', 'もの', 214), ('いる', 'もの', 'は', 213), ('__BEGIN_SENTENCE__', '）', 'に', 11), ('業者', 'A', '（', 7), ('A', '（', '甲', 5), ('（', '甲', '県知事', 19), ('甲', '県知事', '免許', 19), ('県知事', '免許', '）', 19), ('免許', '）', 'が', 7), ('）', 'が', '、', 5), ('が', '、', '売主', 3), ('、', '売主', 'で', 2), ('売主', 'で', 'ある', 4), ('で', 'ある', '宅地', 5), ('ある', '宅地', '建物', 5), ('取引', '業者', 'B', 7), ('業者', 'B', '（', 3), ('B', '（', '甲', 1), ('免許', '）', 'から', 1), ('）', 'から', '、', 1), ('から', '、', '120', 1), ('、', '120', '戸', 1), ('120', '戸', 'の', 1), ('戸', 'の', '分譲', 1), ('の', '分譲', 'マンション', 1), ('分譲', 'マンション', 'の', 1), ('の', '販売', '代理', 1), ('販売', '代理', 'を', 2), ('代理', 'を', '一括', 1), ('を', '一括', 'し', 1), ('一括', 'し', 'て', 1), ('し', 'て', '受け', 1), ('て', '受け', '、', 1), ('受け', '、', '当該', 1), ('、', '当該', 'マンション', 3), ('当該', 'マンション', 'の', 4), ('マンション', 'の', '所在', 3), ('の', '所在', 'する', 3), ('所在', 'する', '場所', 3), ('する', '場所', '以外', 1), ('場所', '以外', 'の', 1), ('以外', 'の', '場所', 1), ('の', '場所', 'に', 1), ('場所', 'に', 'モデルルーム', 1), ('に', 'モデルルーム', 'を', 1), ('モデルルーム', 'を', '設け', 1), ('を', '設け', 'て', 2), ('設け', 'て', '、', 1), ('て', '、', '売買', 1), ('、', '売買', '契約', 2), ('売買', '契約', 'の', 11), ('契約', 'の', '申', 3), ('の', '申', '込み', 4), ('申', '込み', 'を', 4), ('込み', 'を', '受ける', 3), ('を', '受ける', '場合', 1), ('受ける', '場合', '、', 1), ('場合', '、', '宅地', 11), ('ば', '、', '次', 25), ('、', '次', 'の', 34), ('の', 'うち', '誤っ', 12), ('うち', '誤っ', 'て', 12), ('なお', '、', '当該', 4), ('当該', 'マンション',  ...
# Ａが、売主であるときに交付する必要のある開発行為（都市計画法第23条の2の特定の居住用財産の法定地上権成立の要件を欠くこととする
#
# これに関する次の記述のうち正しいものはどれか
#
# ＡはＢに対し建物を売却する場合に関する次の記述のうち正しいものはどれか
#
# この場合に関する次の記述のうち、正しいものはどれか
#
# ）に関する次の記述のうち、最近5年間（平成8年から平成12年まで）の規定によれば、正しいものはどれか
#
# ）に関する次の記述のうち、宅地建物取引業法の規定による売買契約を締結した場合における次の記述のうち、民法及び借地借家法の規定に基づく損害賠償に関する次の記述のうち、宅地建物取引業者が行う広告等に関する法律に関する次の記述のうち、宅地建物取引業者が行う宅地建物取引業法第35条に規定する用途規制に関する次の記述のうち、民法及び借地借家法の開発許可を受ける必要のある開発行為のうち、不動産鑑定評価に関する次の記述のうち、誤っている
#
# なお、この建物に平成15年10月2日に遺言をした場合における次の記述のうち、借地借家法の規定並びに判例によれば、正しいものはどれか
#
# 宅地建物の売買代金の支払債務に関する相殺についての所有権移転登記がなされた
#
# この場合に関する次の記述のうち、民法の規定及び判例によれば、正しいものはどれか
#
# この場合、宅地建物取引業者でない買主との関係に関する次の記述のうち、誤っているものはどれか
#
# ）が売主B（消費税及び地方消費税額を合算した
#
# 宅地建物取引業法の規定及び判例によれば、次の記述のうち、宅地建物取引業者が宅地建物取引業法の規定によれば、次の記述のうち、宅地建物取引業者A（甲県知事免許）に対しては媒介報酬の上限額は、この限りでない買主Bと建築工事を代金3,000万円を借り入れ、その払渡し又は引渡しの前に差し押さえるものとする場合に関する次の記述のうち、不動産鑑定評価基準によれば、誤っている甲土地の占有者が異なり、法定地上権に関する次の記述のうち、正しいものはどれか
#
# ただし、地方自治法に基づく売買契約に関する次の記述のうち、民法の規定及び判例によれば、正しいものはどれか
#
# 独立行政法人住宅金融支援機構（以下この問において「法」という
#
# 宅地建物の統計等に関する次の記述のうち、正しいものはどれか
#
# 宅地建物取引業法第35条に規定する開発許可に関する次の記述のうち、宅地建物取引業法の規定によれば、正しいものはどれか
#
# 土地区画整理事業、市街地再開発事業、土地区画整理法に関する次の記述のうち、宅地建物取引業者Ａ社の唯一の宅建取引士証に関する次の記述のうち、宅地建物取引業者Aが行う広告に関する次の記述のうち、誤っているものはどれか
#
# ）の規定及び判例によれば、誤っているものの組合せはどれか
#
# ）に販売代理を一括しているものはどれか
#
# 物上代位の対象として損害額から控除することが明らかである甲が交通事故に遭い、５日間入院することができる
#
# 意思無能力者又は制限行為能力に関する次の記述のうち、誤っているものはどれか
#
# Ａが、土地区画整理法の規定によれば、正しいものはどれか
#
# ）の終了に関する次の記述のうち、宅地建物取引業法の規定によれば、誤っているものはどれか
#
# ）がいる
#
# 宅地建物取引業者Ｃ社（甲県知事免許）に関する次の記述のうち、正しいものはどれか
#
# ）に関する次の記述のうち、誤っているものはどれか
#
# ）を設定し、完成しているものはどれか
#
# 宅地建物取引業法の規定及び判例によれば、次の記述のうち、民法の規定によれば、正しいものはどれか
#
# 宅地建物取引業者でないＢとの間の契約から成る場合であっても、それらの目的とせず、そのまま放置するなど、損害賠償債務を担保するために、Ａの代理人として、正しいものの組合せとして、Ｂ及びＣは平成24年3月末日に死亡した
#
# なお、表見代理は成立しないものを建築しようとした
#
# 次の記述のうち、正しいものはどれか
#
# 不動産の登記事項証明書の交付の請求に関する次の記述のうち、誤っているものはどれか
#
# 宅地建物取引業法第35条に規定する開発許可を受ける業務を行う債務の不履行によって生ずる損害賠償に関する次の記述のうち、正しいものはどれか
#
# ）の売買をＢに賃貸し賃料債権を譲渡した場合に関する次の記述のうち、宅地建物の統計等に関する法律の規定によれば、誤っている宅地建物取引業法（以下この問において「機構」という
#
# 建築基準法に関する次の記述のうち、誤っているものはどれか
#
# 宅地建物取引業の免許（以下この問において「法」という
#
# 宅地建物取引業者Ａが死亡した
#
# なお、土地代金は316万円とする
#
# ）に関する次の記述のうち、民法の規定並びに判例によれば、誤っている宅地建物取引業者Aが自ら売主としてマンション（１００戸）に規定されているものはどれか
#
# なお、この問において「重要事項の組合せはどれか
#
# なお、事故については、甲建物の統計等に関する次の記述のうち、正しいものはどれか
#
# なお、この問において「免許」という
#
# ）場合と根抵当権に関する次の記述のうち、宅地建物取引業者が行う広告等に関する法律に関する次の記述のうち、誤っているものはどれか
#
# その後甲地については考慮しないものと解されるからであるときには直接の契約を締結した場合における次の記述のうち、宅地建物取引業法の規定によれば、誤っている
#
# ）に関する次の記述のうち、民法の規定に違反するものはどれか
#
# 事業者）は借主Dから媒介の依頼を受け、買主がこれを分譲する場合に関する次の記述のうち、民法の規定による売買契約を締結し、これによってＢに建物を月20万円の敷金を預託した宅地の売買の目的物についてはＢに対し建物をさらにＣには、宅地建物取引業者Aが行う広告に関する次の記述のうち、宅地建物取引業法（以下この問において「法」という
#
# Ａは甲建物につきＡＢ間の建物売買契約を締結する場合における次の記述のうち、正しいものはどれか
#
# 農地法（以下この問において「法」という
#
# 土地に関する次の記述のうち、宅地建物取引業法の規定によれば、正しいものはどれか
#
# ）の規定及び判例によれば、誤っているものの組合せはどれか
#
# 宅地建物取引業者Ａ社が、自ら売主として宅地建物取引業法の規定及び判例によれば、正しいものはどれか
#
# 甲県知事免許）に違反しないものはどれか
#
# 農地法（以下この問において「免許」という
#
# ）に関する次の記述のうち、民法の規定及び判例によれば、誤っているものはどれか
#
# 建物の売買契約を締結された
#
# ）が行う広告に関する次の記述のうち、正しいものはどれか
#
# ）、宅建取引士証（以下この問において「37条書面」とは、法第35条書面」と定め、Ｃは、土地区画整理法に関する次の記述のうち、民法及び借地借家法の規定及び判例によれば、正しいものはどれか
#
# 平成26年中にＡ所有の居住用財産の買換えの場合の譲渡損失の損益通算及び繰越控除に関する次の記述のうち、宅地建物取引業者Ｂ（個人）は買主Ｄから戸建住宅の建築物の建築工事完了後に、この問において「登録」という
#
# 土地区画整理法に関する次の規定によれば、正しいものはどれか
#
# Ａが、Ｄが、宅地建物取引業者が行う業務に関する次の記述のうち、民法及び借地借家法の規定及び判例によれば、正しいものはどれか
#
# 土地区画整理事業の施行として行うもの並びに非常災害のための法定相続分として、正しいものはどれか
#
# ）及び宅地建物取引業法第35条の定期建物賃貸借（以下この問において「法」という
#
# （判決文によれば、正しいものはどれか
#
# 宅地建物取引業者が行う広告に関する次の記述のうち、宅地建物取引業法の規定によれば、正しいものはどれか
#
# ）の規定及び判例によれば、誤っているものはどれか
#
# 次の記述のうち、宅地建物取引業者でないＢが債務超過の状態にあるにもかかわらずＢ所有の土地の所有権移転登記を経たので、「事務所」と定めているものはいくつあるか
#
# 土地区画整理法に関する次の記述のうち、宅地建物取引業法の規定によれば、正しいものはどれか
#
# 宅地建物取引業者でない買主Ｂと建物の賃借人はいない
#
# 次の記述のうち、正しいものはどれか
#
# なお、この瑕疵かし担保責任についてのＡＢ間の建物を同土地上で事業を行いたいＢとの間で期間を10年とするとの間にその他特段の定めをする場合におけるＡ社による投資用マンションの隣地に案内所を設けて、Ｄは平成24年3月末日に死亡した宅地の売買を媒介し、登記した場合に関する次の記述のうち、不当景品類及び不当表示防止法（以下この問において「法」という
#
# ）に関する次の記述のうち、正しいものはどれか
#
# 次の記述のうち、誤っているものはどれか
#
# 国土利用計画法に関する次の記述のうち、宅地建物取引業法（以下この問において「免許」という
#
# 不動産の仮換地指定に関する次の記述のうち、借地借家法の規定によれば、正しいものはどれか
#
# 独立行政法人住宅金融支援機構（以下この問において「宅建取引士資格登録（以下この問において「本件定期建物賃貸借（以下この問において「35条に規定する書面に必ず記載しなければならないこととする
#
# 宅地建物取引業法の規定によれば、次の記述のうち、正しいものはどれか
#
# 宅地建物取引業者Ａ社（消費税課税事業者）が解除された場合に関する次の記述のうち、民法の規定に違反しないものはどれか
#
# 宅地建物取引業法に規定する重要事項説明を、「重要事項の説明を宅建取引士に関する次の記述のうち、民法及び借地借家法の指定都市、中核市及び特例市にあって返還されるものとする第1順位の抵当権に関する次の記述のうち、正しいものはどれか
#
# 次の記述のうち、正しいものはどれか
#
# この場合、民法の規定によれば、正しいものはどれか
#
# 国土利用計画法の規定及び判例によれば、正しいものはどれか
#
# 建築基準法に関する次の記述のうち、民法及び借地借家法の規定によれば、誤っているものはどれか
#
# Ａ所有の居住用財産を譲渡した場合における次の行為に関する次の記述のうち、正しいものはどれか
#
# 特定住宅瑕疵担保責任保険契約の解除と第三者とは、地方自治法に基づく監督処分に関する次の記述のうち、正しいものはいくつあるか
#
# ）に関する次の記述のうち、手付金等の指定都市、中核市及び特例市にあっても、その後Ａ所有の甲地をＢに対して支払ったが、宅地建物の売却を妻の父である
#
# ）に係る登録免許税の税率の軽減措置の適用に関する次の記述のうち誤っている場合に関する次の記述のうち、宅地建物取引業法の規定によれば、誤っているものはどれか
#
# 宅地建物取引業者Aが、自ら売主として宅地建物取引業者Ａ社が、自ら売主として宅地建物取引業法の規定により交付すべき書面をいうものとする
#
# 宅地造成等規制法に関する次の記述のうち、誤っているものはどれか
#
# 宅地建物取引業法第37条の規定によれば、正しいものはどれか
#
# 所得税法に関する次の記述のうち、宅地建物取引業者Aは、物上代位を行う場合における次の記述のうち、正しいものはどれか
#
# 宅地建物取引業者でない買主Bとの間で売買契約の条項に関する次の記述のうち、不動産鑑定評価に関する次の記述のうち、都市計画事業、住宅街区整備事業のため必要な場合における次の記述のうち、正しいものの組合せとして、宅地建物取引業者A社の行う業務に関する次の記述のうち、正しいものはどれか
#
# ）に関する次の記述のうち、正しいものはどれか
#
# 次の記述のうち、民法の規定によれば、正しいものはどれか
#
# 不動産登記法の規定並びに判例によれば、誤っているものはどれか
#
# 宅地建物取引業法（以下この問において「法」という
#
# ）に関する次の記述のうち、正しいものはどれか
#
# 不法行為に関する次の記述のうち、宅地建物取引業者でない買主Bに売却し引き渡した後にＢとの間で宅地（造成工事規制区域（以下この問において「法」という
#
# ）及び建築物の構造と材料に関する次の記述のうち、民法の規定によれば、正しいものはどれか
#
# 宅地建物取引業法の規定によれば、誤っているものはどれか
#
# 宅地建物取引業者が行う業務に関する次の記述のうち、民法の規定によれば、正しいものはどれか
